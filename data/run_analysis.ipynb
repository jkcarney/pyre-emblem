# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("trainingrun2.csv")

data.drop(['Unnamed: 0'], axis=1, inplace=True)

data.head(10)
# Out:
#    game_number victory_rank survival_rank tactic_rank overall_rank  \
# 0            0            F             A           S            D
# 1            1            F             B           S            D
# 2            2            F             A           S            D
# 3            3            S             S           S            S
# 4            4            F             A           S            D
# 5            5            F             S           S            D
# 6            6            S             S           S            S
# 7            7            S             S           A            S
# 8            8            S             S           S            S
# 9            9            S             S           S            S
#
#                   units
# 0       Kent-Lucius-Lyn
# 1       Matthew-Guy-Lyn
# 2  Matthew-Heath-Hector
# 3       Rath-Bartre-Lyn
# 4   Florina-Rebecca-Lyn
# 5        Raven-Rath-Lyn
# 6  Lucius-Marcus-Hector
# 7      Marcus-Oswin-Lyn
# ...

# %%
data['victory_rank'].value_counts()
# Out:
# S    82518
# F    17482
# Name: victory_rank, dtype: int64

# %%
y_space = np.arange(0, 100000, 10000)

plt.figure(figsize=(6,10))
plt.yticks(y_space)
sns.violinplot(x='victory_rank', y='game_number', data=data)
# Out:
# <AxesSubplot:xlabel='victory_rank', ylabel='game_number'>

# %%
sns.catplot(x='victory_rank', y='game_number', data=data, s=0.5, height=8, aspect=8/14).set(yticks=y_space)

# %% [markdown]
# no learning???
